# %% [markdown]
# <img src="http://dask.readthedocs.io/en/latest/_images/dask_horizontal.svg"
#      align="right"
#      width="30%"
#      alt="Dask logo">
#
# DataFrames on a Cluster
# =======================
#
# <img src="https://upload.wikimedia.org/wikipedia/commons/thumb/e/ed/Pandas_logo.svg/600px-Pandas_logo.svg.png"
#      align="left"
#      width="50%"
#      alt="Pandas logo">

# %%
from pathlib import Path

data_root = Path('/Volumes/dask')

# %%
list(data_root.glob("*csv"))
# Out:
# [PosixPath('/Volumes/dask/yellow_tripdata_2015-01.csv'),
#  PosixPath('/Volumes/dask/yellow_tripdata_2015-02.csv'),
#  PosixPath('/Volumes/dask/yellow_tripdata_2015-03.csv'),
#  PosixPath('/Volumes/dask/yellow_tripdata_2015-04.csv'),
#  PosixPath('/Volumes/dask/yellow_tripdata_2015-05.csv'),
#  PosixPath('/Volumes/dask/yellow_tripdata_2015-06.csv'),
#  PosixPath('/Volumes/dask/yellow_tripdata_2015-07.csv'),
#  PosixPath('/Volumes/dask/yellow_tripdata_2015-08.csv'),
#  PosixPath('/Volumes/dask/yellow_tripdata_2015-09.csv'),
#  PosixPath('/Volumes/dask/yellow_tripdata_2015-10.csv'),
#  PosixPath('/Volumes/dask/yellow_tripdata_2015-11.csv'),
#  PosixPath('/Volumes/dask/yellow_tripdata_2015-12.csv')]

# %%
list(data_root.glob("*csv"))[0]
# Out:
# PosixPath('/Volumes/dask/yellow_tripdata_2015-01.csv')

# %% [markdown]
# ### Read single dataframe from S3 with Pandas

# %%
from s3fs import S3FileSystem

s3 = S3FileSystem(anon=True)
s3.ls('dask-data/nyc-taxi/2015/')
# Out:
# ['dask-data/nyc-taxi/2015/',
#  'dask-data/nyc-taxi/2015/parquet',
#  'dask-data/nyc-taxi/2015/parquet.gz',
#  'dask-data/nyc-taxi/2015/yellow_tripdata_2015-01.csv',
#  'dask-data/nyc-taxi/2015/yellow_tripdata_2015-01.parq',
#  'dask-data/nyc-taxi/2015/yellow_tripdata_2015-02.csv',
#  'dask-data/nyc-taxi/2015/yellow_tripdata_2015-03.csv',
#  'dask-data/nyc-taxi/2015/yellow_tripdata_2015-04.csv',
#  'dask-data/nyc-taxi/2015/yellow_tripdata_2015-05.csv',
#  'dask-data/nyc-taxi/2015/yellow_tripdata_2015-06.csv',
#  'dask-data/nyc-taxi/2015/yellow_tripdata_2015-07.csv',
#  'dask-data/nyc-taxi/2015/yellow_tripdata_2015-08.csv',
#  'dask-data/nyc-taxi/2015/yellow_tripdata_2015-09.csv',
#  'dask-data/nyc-taxi/2015/yellow_tripdata_2015-10.csv',
#  'dask-data/nyc-taxi/2015/yellow_tripdata_2015-11.csv',
#  'dask-data/nyc-taxi/2015/yellow_tripdata_2015-12.csv']

# %%
for path in s3.ls('dask-data/nyc-taxi/2015/'):
    with s3.open(path) as f:
        print(f.url())
# Out:
# https://dask-data.s3.amazonaws.com/nyc-taxi/2015
# https://dask-data.s3.amazonaws.com/nyc-taxi/2015/parquet
# https://dask-data.s3.amazonaws.com/nyc-taxi/2015/parquet.gz
# https://dask-data.s3.amazonaws.com/nyc-taxi/2015/yellow_tripdata_2015-01.csv
# https://dask-data.s3.amazonaws.com/nyc-taxi/2015/yellow_tripdata_2015-01.parq
# https://dask-data.s3.amazonaws.com/nyc-taxi/2015/yellow_tripdata_2015-02.csv
# https://dask-data.s3.amazonaws.com/nyc-taxi/2015/yellow_tripdata_2015-03.csv
# https://dask-data.s3.amazonaws.com/nyc-taxi/2015/yellow_tripdata_2015-04.csv
# https://dask-data.s3.amazonaws.com/nyc-taxi/2015/yellow_tripdata_2015-05.csv
# https://dask-data.s3.amazonaws.com/nyc-taxi/2015/yellow_tripdata_2015-06.csv
# https://dask-data.s3.amazonaws.com/nyc-taxi/2015/yellow_tripdata_2015-07.csv
# https://dask-data.s3.amazonaws.com/nyc-taxi/2015/yellow_tripdata_2015-08.csv
# https://dask-data.s3.amazonaws.com/nyc-taxi/2015/yellow_tripdata_2015-09.csv
# https://dask-data.s3.amazonaws.com/nyc-taxi/2015/yellow_tripdata_2015-10.csv
# https://dask-data.s3.amazonaws.com/nyc-taxi/2015/yellow_tripdata_2015-11.csv
# https://dask-data.s3.amazonaws.com/nyc-taxi/2015/yellow_tripdata_2015-12.csv

# %%
with s3.open('dask-data/nyc-taxi/2015/yellow_tripdata_2015-01.csv') as f:
    print(f.url())
# Out:
# https://dask-data.s3.amazonaws.com/nyc-taxi/2015/yellow_tripdata_2015-01.csv

# %%
import pandas as pd

with s3.open('dask-data/nyc-taxi/2015/yellow_tripdata_2015-01.csv') as f:
    df = pd.read_csv(f, nrows=5, parse_dates=['tpep_pickup_datetime', 'tpep_dropoff_datetime'])
df
# Out:
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0         2  2015-01-15 19:05:39   2015-01-15 19:23:42                1
# 1         1  2015-01-10 20:33:38   2015-01-10 20:53:28                1
# 2         1  2015-01-10 20:33:38   2015-01-10 20:43:41                1
# 3         1  2015-01-10 20:33:39   2015-01-10 20:35:31                1
# 4         1  2015-01-10 20:33:39   2015-01-10 20:52:58                1
#
#    trip_distance  pickup_longitude  pickup_latitude  RateCodeID  \
# 0           1.59        -73.993896        40.750111           1
# 1           3.30        -74.001648        40.724243           1
# 2           1.80        -73.963341        40.802788           1
# 3           0.50        -74.009087        40.713818           1
# 4           3.00        -73.971176        40.762428           1
#
#   store_and_fwd_flag  dropoff_longitude  dropoff_latitude  payment_type  \
# 0                  N         -73.974785         40.750618             1
# 1                  N         -73.994415         40.759109             1
# 2                  N         -73.951820         40.824413             2
# 3                  N         -74.004326         40.719986             2
# 4                  N         -74.004181         40.742653             2
#
#    fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# 0         12.0    1.0      0.5        3.25             0
# 1         14.5    0.5      0.5        2.00             0
# 2          9.5    0.5      0.5        0.00             0
# 3          3.5    0.5      0.5        0.00             0
# 4         15.0    0.5      0.5        0.00             0
#
#    improvement_surcharge  total_amount
# 0                    0.3         17.05
# 1                    0.3         17.80
# 2                    0.3         10.80
# 3                    0.3          4.80
# 4                    0.3         16.30

# %%
with list(data_root.glob("*csv"))[0].open() as f:
    df = pd.read_csv(f, nrows=5, parse_dates=['tpep_pickup_datetime', 'tpep_dropoff_datetime'])
df
# Out:
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0         2  2015-01-15 19:05:39   2015-01-15 19:23:42                1
# 1         1  2015-01-10 20:33:38   2015-01-10 20:53:28                1
# 2         1  2015-01-10 20:33:38   2015-01-10 20:43:41                1
# 3         1  2015-01-10 20:33:39   2015-01-10 20:35:31                1
# 4         1  2015-01-10 20:33:39   2015-01-10 20:52:58                1
#
#    trip_distance  pickup_longitude  pickup_latitude  RateCodeID  \
# 0           1.59        -73.993896        40.750111           1
# 1           3.30        -74.001648        40.724243           1
# 2           1.80        -73.963341        40.802788           1
# 3           0.50        -74.009087        40.713818           1
# 4           3.00        -73.971176        40.762428           1
#
#   store_and_fwd_flag  dropoff_longitude  dropoff_latitude  payment_type  \
# 0                  N         -73.974785         40.750618             1
# 1                  N         -73.994415         40.759109             1
# 2                  N         -73.951820         40.824413             2
# 3                  N         -74.004326         40.719986             2
# 4                  N         -74.004181         40.742653             2
#
#    fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# 0         12.0    1.0      0.5        3.25             0
# 1         14.5    0.5      0.5        2.00             0
# 2          9.5    0.5      0.5        0.00             0
# 3          3.5    0.5      0.5        0.00             0
# 4         15.0    0.5      0.5        0.00             0
#
#    improvement_surcharge  total_amount
# 0                    0.3         17.05
# 1                    0.3         17.80
# 2                    0.3         10.80
# 3                    0.3          4.80
# 4                    0.3         16.30

# %% [markdown]
# ### Parallelize Pandas with Dask.dataframe

# %%
from dask.distributed import Client, progress
client = Client('127.0.0.1:8786')
client
# Out:
# <Client: 'tcp://192.168.178.105:8786' processes=3 threads=34, memory=137.44 GB>

# %%
client.restart()
# Out:
# <Client: 'tcp://192.168.178.105:8786' processes=2 threads=28, memory=68.72 GB>

# %%
import dask.dataframe as dd

df = dd.read_csv('s3://dask-data/nyc-taxi/2015/*.csv', 
                 parse_dates=['tpep_pickup_datetime', 'tpep_dropoff_datetime'],
                 storage_options={'anon': True})

# %%
import dask.dataframe as dd

df = dd.read_csv('/Volumes/dask/*.csv', 
                 parse_dates=['tpep_pickup_datetime', 'tpep_dropoff_datetime'],
                 storage_options={'anon': True})

# %%
df = client.persist(df)
progress(df)
# Out:
# VBox()

# %% [markdown]
# Dask DataFrames
# ---------------
#
# *  Coordinate many Pandas DataFrames across a cluster
# *  Faithfully implement a subset of the Pandas API
# *  Use Pandas under the hood (for speed and maturity)

# %%
df
# Out:
# Dask DataFrame Structure:
#                 VendorID tpep_pickup_datetime tpep_dropoff_datetime passenger_count trip_distance pickup_longitude pickup_latitude RateCodeID store_and_fwd_flag dropoff_longitude dropoff_latitude payment_type fare_amount    extra  mta_tax tip_amount tolls_amount improvement_surcharge total_amount
# npartitions=365
#                    int64       datetime64[ns]        datetime64[ns]           int64       float64          float64         float64      int64             object           float64          float64        int64     float64  float64  float64    float64      float64               float64      float64
#                      ...                  ...                   ...             ...           ...              ...             ...        ...                ...               ...              ...          ...         ...      ...      ...        ...          ...                   ...          ...
# ...                  ...                  ...                   ...             ...           ...              ...             ...        ...                ...               ...              ...          ...         ...      ...      ...        ...          ...                   ...          ...
#                      ...                  ...                   ...             ...           ...              ...             ...        ...                ...               ...              ...          ...         ...      ...      ...        ...          ...                   ...          ...
#                      ...                  ...                   ...             ...           ...              ...             ...        ...                ...               ...              ...          ...         ...      ...      ...        ...          ...                   ...          ...
# Dask Name: read-csv, 365 tasks

# %%
df.dtypes
# Out:
# VendorID                          int64
# tpep_pickup_datetime     datetime64[ns]
# tpep_dropoff_datetime    datetime64[ns]
# passenger_count                   int64
# trip_distance                   float64
# pickup_longitude                float64
# pickup_latitude                 float64
# RateCodeID                        int64
# store_and_fwd_flag               object
# dropoff_longitude               float64
# dropoff_latitude                float64
# payment_type                      int64
# fare_amount                     float64
# extra                           float64
# mta_tax                         float64
# tip_amount                      float64
# tolls_amount                    float64
# improvement_surcharge           float64
# total_amount                    float64
# dtype: object

# %%
df.head()
# Out:
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0         2  2015-01-15 19:05:39   2015-01-15 19:23:42                1
# 1         1  2015-01-10 20:33:38   2015-01-10 20:53:28                1
# 2         1  2015-01-10 20:33:38   2015-01-10 20:43:41                1
# 3         1  2015-01-10 20:33:39   2015-01-10 20:35:31                1
# 4         1  2015-01-10 20:33:39   2015-01-10 20:52:58                1
#
#    trip_distance  pickup_longitude  pickup_latitude  RateCodeID  \
# 0           1.59        -73.993896        40.750111           1
# 1           3.30        -74.001648        40.724243           1
# 2           1.80        -73.963341        40.802788           1
# 3           0.50        -74.009087        40.713818           1
# 4           3.00        -73.971176        40.762428           1
#
#   store_and_fwd_flag  dropoff_longitude  dropoff_latitude  payment_type  \
# 0                  N         -73.974785         40.750618             1
# 1                  N         -73.994415         40.759109             1
# 2                  N         -73.951820         40.824413             2
# 3                  N         -74.004326         40.719986             2
# 4                  N         -74.004181         40.742653             2
#
#    fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# 0         12.0    1.0      0.5        3.25           0.0
# 1         14.5    0.5      0.5        2.00           0.0
# 2          9.5    0.5      0.5        0.00           0.0
# 3          3.5    0.5      0.5        0.00           0.0
# 4         15.0    0.5      0.5        0.00           0.0
#
#    improvement_surcharge  total_amount
# 0                    0.3         17.05
# 1                    0.3         17.80
# 2                    0.3         10.80
# 3                    0.3          4.80
# 4                    0.3         16.30

# %%
# %time len(df)
# Out:
# CPU times: user 316 ms, sys: 12.2 ms, total: 328 ms
# Wall time: 15.5 s
# 146112989

# %%
df.memory_usage().compute().sum()
# Out:
# 22209221048

# %%
# %time df.passenger_count.sum().compute()
# Out:
# CPU times: user 117 ms, sys: 8.28 ms, total: 125 ms
# Wall time: 5.5 s
# 245566747

# %%
# Compute average trip distance grouped by passenger count
# %time df.groupby(df.passenger_count).trip_distance.mean().compute()
# Out:
# CPU times: user 124 ms, sys: 6.06 ms, total: 130 ms
# Wall time: 10.6 s
# passenger_count
# 0     2.279183
# 1    15.541413
# 2    11.815871
# 3     1.620052
# 4     7.481066
# 5     3.066019
# 6     2.977158
# 9     5.459763
# 7     3.303054
# 8     3.866298
# Name: trip_distance, dtype: float64

# %% [markdown]
# ### Tip Fraction, grouped by day-of-week and hour-of-day

# %%
df2 = df[(df.tip_amount > 0) & (df.fare_amount > 0)]
df2['tip_fraction'] = df2.tip_amount / df2.fare_amount

# %%
# Group df.tpep_pickup_datetime by dayofweek and hour
dayofweek = df2.groupby(df2.tpep_pickup_datetime.dt.dayofweek).tip_fraction.mean() 
hour = df2.groupby(df2.tpep_pickup_datetime.dt.hour).tip_fraction.mean()

dayofweek, hour = client.persist([dayofweek, hour])
progress(dayofweek, hour)
# Out:
# VBox()

# %% [markdown]
# ### Plot results

# %%
from bokeh.plotting import figure, output_notebook, show
output_notebook()

fig = figure(title='Tip Fraction',
             x_axis_label='Hour of day',
             y_axis_label='Tip Fraction',
             height=300)
fig.line(x=hour.index.compute(), y=hour.compute(), line_width=3)
fig.y_range.start = 0

show(fig)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1001">Loading BokehJS ...</span>
#     </div>
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-23-28ef9aafef7b> in <module>
#       6              y_axis_label='Tip Fraction',
#       7              height=300)
# ----> 8 fig.line(x=hour.index.compute(), y=hour.compute(), line_width=3)
#       9 fig.y_range.start = 0
#      10
#
# ~/.pyenv/versions/3.8.3/envs/ds/lib/python3.8/site-packages/dask/base.py in compute(self, **kwargs)
#     164         dask.base.compute
#     165         """
# --> 166         (result,) = compute(self, traverse=False, **kwargs)
#     167         return result
#     168
#
# ~/.pyenv/versions/3.8.3/envs/ds/lib/python3.8/site-packages/dask/base.py in compute(*args, **kwargs)
#     442         postcomputes.append(x.__dask_postcompute__())
#     443
# --> 444     results = schedule(dsk, keys, **kwargs)
#     445     return repack([f(r, *a) for r, (f, a) in zip(results, postcomputes)])
#     446
#
# ~/.pyenv/versions/3.8.3/envs/ds/lib/python3.8/site-packages/distributed/client.py in get(self, dsk, keys, restrictions, loose_restrictions, resources, sync, asynchronous, direct, retries, priority, fifo_timeout, actors, **kwargs)
#    2680                     should_rejoin = False
#    2681             try:
# -> 2682                 results = self.gather(packed, asynchronous=asynchronous, direct=direct)
#    2683             finally:
#    2684                 for f in futures.values():
#
# ~/.pyenv/versions/3.8.3/envs/ds/lib/python3.8/site-packages/distributed/client.py in gather(self, futures, errors, direct, asynchronous)
#    1974             else:
#    1975                 local_worker = None
# -> 1976             return self.sync(
#    1977                 self._gather,
#    1978                 futures,
#
# ~/.pyenv/versions/3.8.3/envs/ds/lib/python3.8/site-packages/distributed/client.py in sync(self, func, asynchronous, callback_timeout, *args, **kwargs)
#     829             return future
#     830         else:
# --> 831             return sync(
#     832                 self.loop, func, *args, callback_timeout=callback_timeout, **kwargs
#     833             )
#
# ~/.pyenv/versions/3.8.3/envs/ds/lib/python3.8/site-packages/distributed/utils.py in sync(loop, func, callback_timeout, *args, **kwargs)
#     337     if error[0]:
#     338         typ, exc, tb = error[0]
# --> 339         raise exc.with_traceback(tb)
#     340     else:
#     341         return result[0]
#
# ~/.pyenv/versions/3.8.3/envs/ds/lib/python3.8/site-packages/distributed/utils.py in f()
#     321             if callback_timeout is not None:
#     322                 future = asyncio.wait_for(future, callback_timeout)
# --> 323             result[0] = yield future
#     324         except Exception as exc:
#     325             error[0] = sys.exc_info()
#
# ~/.pyenv/versions/3.8.3/envs/ds/lib/python3.8/site-packages/tornado/gen.py in run(self)
#     733
#     734                     try:
# --> 735                         value = future.result()
#     736                     except Exception:
#     737                         exc_info = sys.exc_info()
#
# ~/.pyenv/versions/3.8.3/envs/ds/lib/python3.8/site-packages/distributed/client.py in _gather(self, futures, errors, direct, local_worker)
#    1839                             exc = CancelledError(key)
#    1840                         else:
# -> 1841                             raise exception.with_traceback(traceback)
#    1842                         raise exc
#    1843                     if errors == "skip":
#
# ~/.pyenv/versions/3.8.3/envs/ds/lib/python3.8/site-packages/dask/dataframe/groupby.py in _apply_chunk()
#     293         if isinstance(columns, (tuple, list, set, pd.Index)):
#     294             columns = list(columns)
# --> 295         return func(g[columns], **kwargs)
#     296
#     297
#
# ~/.pyenv/versions/3.8.3/envs/ds/lib/python3.8/site-packages/dask/utils.py in __call__()
#     893
#     894     def __call__(self, obj, *args, **kwargs):
# --> 895         return getattr(obj, self.method)(*args, **kwargs)
#     896
#     897     def __reduce__(self):
#
# ~/.pyenv/versions/3.8.3/envs/ds/lib/python3.8/site-packages/pandas/core/groupby/groupby.py in f()
#    1370                 # try a cython aggregation if we can
#    1371                 try:
# -> 1372                     return self._cython_agg_general(alias, alt=npfunc, **kwargs)
#    1373                 except DataError:
#    1374                     pass
#
# ~/.pyenv/versions/3.8.3/envs/ds/lib/python3.8/site-packages/pandas/core/groupby/groupby.py in _cython_agg_general()
#     888                 continue
#     889
# --> 890             result, agg_names = self.grouper.aggregate(
#     891                 obj._values, how, min_count=min_count
#     892             )
#
# ~/.pyenv/versions/3.8.3/envs/ds/lib/python3.8/site-packages/pandas/core/groupby/ops.py in aggregate()
#     584         self, values, how: str, axis: int = 0, min_count: int = -1
#     585     ) -> Tuple[np.ndarray, Optional[List[str]]]:
# --> 586         return self._cython_operation(
#     587             "aggregate", values, how, axis, min_count=min_count
#     588         )
#
# ~/.pyenv/versions/3.8.3/envs/ds/lib/python3.8/site-packages/pandas/core/groupby/ops.py in _cython_operation()
#     527             )
#     528             counts = np.zeros(self.ngroups, dtype=np.int64)
# --> 529             result = self._aggregate(
#     530                 result, counts, values, codes, func, is_datetimelike, min_count
#     531             )
#
# ~/.pyenv/versions/3.8.3/envs/ds/lib/python3.8/site-packages/pandas/core/groupby/ops.py in _aggregate()
#     606             agg_func(result, counts, values, comp_ids, rank=1, min_count=-1)
#     607         else:
# --> 608             agg_func(result, counts, values, comp_ids, min_count)
#     609
#     610         return result
#
# pandas/_libs/groupby.pyx in pandas._libs.groupby._group_add()
#
# ~/.pyenv/versions/3.8.3/envs/ds/lib/python3.8/site-packages/pandas/_libs/groupby.cpython-38-darwin.so in View.MemoryView.memoryview_cwrapper()
#
# ~/.pyenv/versions/3.8.3/envs/ds/lib/python3.8/site-packages/pandas/_libs/groupby.cpython-38-darwin.so in View.MemoryView.memoryview.__cinit__()
#
# ValueError: buffer source array is read-only

# %%
from bokeh.plotting import figure, output_notebook, show
output_notebook()

fig = figure(title='Tip Fraction',
             x_axis_label='Day of week',
             y_axis_label='Tip Fraction',
             height=300)
fig.line(x=dayofweek.index.compute(), y=dayofweek.compute(), line_width=3)
fig.y_range.start = 0

show(fig)

# %%
del df
del df2
del fig
del hour
del dayofweek
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-43-cfa302ad8311> in <module>
#       1 del df
# ----> 2 del df2
#       3 del fig
#       4 del hour
#       5 del dayofweek
#
# NameError: name 'df2' is not defined

# %%
client.cancel(df)
