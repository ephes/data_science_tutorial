# %% [markdown]
# # Data Science Tutorial
#
# Welche Punkte sollten drin sein?
#
# - Ein motivierendes Beispiel
# - Trainingscore vs Validationscore
# - Crossvalidation
# - Was mit Text
# - Was mit Bildern
#
# ## Motivierendes Beispiel
#
# - Hunde vs Katzen?
# - Reuters?
#
# Deeplearning wäre sinnvoll, weil man sich damit das feature
# engineering spart, aber trotzdem ein beeindruckendes Ergebnis
# hat.
#
# ## Evaluation
#
# - Training vs Valididationerror
# - Bias vs Variance
# - Crossvalidation
# - Grid Search
#
# ## Feature Engineering
#
# - Beispiel TF-IDF
# - Extractin Pipelines
#
# ## Software
#
# - Pandas
# - Jupyter-Notebooks
# - conda environments
# - scikit-learn

# %% [markdown]
# # Machine Learning mit Python
#
# Wäre es nicht schön, wenn Programme mit Erfahrung besser würden?
#
# In den letzten Jahren hat sich gezeigt, dass dies in immer mehr Bereichen
# tatsächlich möglich ist.
#
# Seit einigen Jahren ist Machine Learning nun schon
#
# Machine Learning ist die Grundlage für viele der interessanteren Produkte und
# Dienstleistungen, die in den letzten Jahren von Firmen wie Google, Apple oder
# Facebook vorgestellt wurden.
#
# Da aber die verwendete Software und Infrastruktur frei zugänglich sind, gibt es
# eigentlich keinen Grund, weshalb nicht auch Andere von dieser Entwicklung
# profitieren sollten.

# %% [markdown]
# # Machine Learning mit Python
#
# Machine Learning ist die Grundlage für viele der interessantesten Produkte
# und Dienstleistungen, die in den letzten Jahren vorgestellt wurden. Und auch
# wenn inzwischen Daten als das Öl des 21ten Jahrunderts bezeichnet werden, ohne
#
#
# Schon
# werden Daten als das Öl des 21ten Jahrhunderts bezeichnet..
#
# Auch wenn
# Firmen wie Google, Amazon, Apple oder Facebook hier führend sein mögen und
# auch die me

# %% [markdown]
# # Machine Learning mit Python
#
# Machine Learning als Fachgebiet erhält in den letzten Jahren zunehmend Aufmerksamkeit.
# Es bildet die Grundlage für viele der interessantesten Produkte und Dienstleistungen,
# die im IT-Umfeld heutzutage vorgestellt werden.
#
# Ein Grossteil der Machine-Learning Systeme wird in Python entwickelt, weil viele der
# beliebtesten Softwarebibliotheken entweder direkt in Python geschrieben wurden oder
# zumindest über eine Python-Anbindung verfügen.
#
# Nutzbare Softwareinfrastruktur ist aber nur eine der Vorraussetzungen, um erfolgreich
# Machine-Learning Projekte umsetzen zu können. Eine andere sind Daten. Es ist sicher
# schwer vorstellbar, im gleichen Umfang wie Google Daten erheben und verarbeiten zu
# können. Andererseits ist das aber auch nicht immer erforderlich. Es gibt überraschend
# viele Machine Learning Anwendungen, die sich mit handhabbareren Datenmengen umsetzen
# lassen.
#
# Dieser Kurs bietet einen Überblick über das PyData-Ökosystem und einen Einblick in
# Best Practices und Tools zum Bau von Machine-Learning Systemen in Python. Behandelt
# werden beispielsweise:
#
# - Jupyter Notebooks
# - Numpy/Pandas/Matplotlib
# - Scikit-Learn
# - Keras/Tensorflow

# %% [markdown]
# # Dozenten
#
# Jochen Wersdörfer ist freiberuflicher Softwareentwickler und baut schon seit über zehn Jahren Machine Learning Systeme im Ecommerce-Umfeld.

# %% [markdown]
# # Kursinhalt
#
# ## Machine Learning Einführung
#
# - Was ist das überhaupt?
# - Für welche Art von Problemen wird es verwendet?
# - Überblick über unterschiedliche Verfahren
#
# ### Kleine Beispielanwendung
#
# - conda environment
# - Jupyter-Notebooks
# - Wir bauen ein Modell, das Hunde von Katzen unterscheiden kann
#
# ## Evaluation von Modellen
#
# - Training vs Valididationerror / Bias vs Variance
# - Crossvalidation
# - Grid Search
#
# ## Einführung in Numpy / Pandas
#
# - Datenimport
# - Cleanup, Transformation in geeignetere Formate
# - Visualisierung
#
# ## Feature Engineering
#
# - Estimator Api scikit-learn
# - Pipeline/FeatureUnion
# - Umgang mit fehlenden Daten / Kategorien
#
# ### Beispielanwendung mit Feature Engineering
#
# - Textkategorisierung mit Reuters Dataset
# - TF-IDF als Beispiel für Feature Engineering
#
# ## Optional
#
# - Modell in REST-Api deployen
# - Training auf GPU/TPU Cloudinstanzen
# - Performanceoptimierung cython/numba/dask
# - Modelle auf iOS-Devices deployen (coreML etc.)
# - Beispiel für unüberwachtes Lernen (Clustering)
# - Beispiel für Reinforcement Learning
# - Zeitreihen
# - Texte/Bilder etc mit ML-Modellen generieren

# %% [markdown]
# # Machine Learning mit Python
#
# Machine Learning bekommt in den letzten Jahren immer mehr Aufmerksamkeit. Es bildet die
# Grundlage für viele der interessantesten Produkte und Dienstleistungen, die im IT-Umfeld
# heutzutage vorgestellt werden.
#
# Ein Großteil der Machine-Learning Systeme wird in Python entwickelt. Viele der
# beliebtesten Softwarebibliotheken wurden entweder direkt in Python geschrieben
# oder verfügen zumindest über eine Python-Anbindung.
#
# Nutzbare Softwareinfrastruktur ist aber nur eine der Vorraussetzungen, um erfolgreich
# Machine-Learning Projekte umsetzen zu können. Eine andere sind Daten. Alle Welt spricht
# heute von BigData, dabei dürfte kaum jemand im gleichen Umfang wie beispielsweise
# Google Daten erheben und verarbeiten. Glücklicherweise ist das aber auch nicht
# zwingend erforderlich. Es gibt überraschend viele Machine Learning Anwendungen, die
# sich mit handhabbareren Datenmengen umsetzen lassen.
#
# Dieser Kurs bietet einen Überblick über das PyData-Ökosystem und einen Einblick in
# Best Practices und Tools zum Bau von Machine-Learning Systemen in Python. Behandelt
# werden unter anderem:
#
# - Jupyter Notebooks
# - Numpy/Pandas/Matplotlib
# - Scikit-Learn
# - Keras/Tensorflow
#
# # Dozenten
#
# Jochen Wersdörfer arbeitet freiberuflich als Softwareentwickler und baut seit über zehn
# Jahren Machine-Learning Systeme im Ecommerce-Umfeld.
#
# # Kursinhalt
#
# ## Einführung Machine Learning
#
# - Was ist das überhaupt?
# - Für welche Art von Problemen wird es verwendet?
# - Überblick über unterschiedliche Verfahren
#
# ### Bilderkennung als Beispielanwendung
#
# - conda environment
# - Jupyter-Notebooks
# - Wir bauen ein Modell, das Hunde von Katzen unterscheiden kann
#
# ## Evaluation von Modellen
#
# - Training vs Valididationerror / Bias vs Variance
# - Crossvalidation
# - Grid Search
#
# ## Einführung in Numpy / Pandas
#
# - Datenimport
# - Cleanup, Transformation in geeignetere Formate
# - Visualisierung
#
# ## Feature Engineering
#
# - Estimator Api scikit-learn
# - Pipeline/FeatureUnion
# - Umgang mit fehlenden Daten / Kategorien
#
# ### Beispielanwendung mit Feature Engineering
#
# - Textkategorisierung mit Reuters Dataset
# - TF-IDF als Beispiel für Feature Engineering
#
# ## Optional
#
# - Modell in REST-Api deployen
# - Training auf GPU/TPU Cloudinstanzen
# - Performanceoptimierung cython/numba/dask
# - Modelle auf iOS-Devices deployen (coreML etc.)
# - Beispiel für unüberwachtes Lernen (Clustering)
# - Beispiel für Reinforcement Learning
# - Zeitreihen
# - Texte/Bilder etc mit ML-Modellen generieren
