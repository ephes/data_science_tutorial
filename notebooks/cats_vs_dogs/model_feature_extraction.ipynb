# %%
# %config InlineBackend.figure_format = 'retina'

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %% [markdown]
# # Set up directories

# %%
from pathlib import Path
data_root = Path.home() / "data" / "tmp"
sample_dir = data_root / "cats_vs_dogs_sample"

# %% [markdown]
# # Use an existing deep learning model for feature extraction

# %% [markdown]
# ## Create model

# %%
from keras.applications import VGG16

conv_base = VGG16(weights='imagenet', include_top=False, input_shape=(150, 150, 3))
# Out:
# Using TensorFlow backend.
# A local file was found, but it seems to be incomplete or outdated because the auto file hash does not match the original value of 6d6bbae143d832006294945121d1f1fc so we will re-download the data.
# Downloading data from https://github.com/fchollet/deep-learning-models/releases/download/v0.1/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58892288/58889256 [==============================] - 31s 1us/step

# %%
conv_base.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 150, 150, 3)       0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 150, 150, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 150, 150, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 75, 75, 64)        0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 75, 75, 128)       73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 75, 75, 128)       147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 37, 37, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 37, 37, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 37, 37, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 37, 37, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 18, 18, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 18, 18, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 18, 18, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 18, 18, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 9, 9, 512)         0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 9, 9, 512)         2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 9, 9, 512)         2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 9, 9, 512)         2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 4, 4, 512)         0
# =================================================================
# Total params: 14,714,688
# Trainable params: 14,714,688
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Create training data generator

# %%
import numpy as np
from keras.preprocessing.image import ImageDataGenerator

# %%
# %%time
datagen = ImageDataGenerator(rescale=1./255)
batch_size = 20

def extract_features(directory, sample_count):
    features = np.zeros(shape=(sample_count, 4, 4, 512))
    labels = np.zeros(shape=(sample_count))
    generator = datagen.flow_from_directory(
        directory,
        target_size=(150, 150),
        batch_size=batch_size,
        class_mode='binary')
    for i, (inputs_batch, labels_batch) in enumerate(generator):
        features_batch = conv_base.predict(inputs_batch)
        features[i * batch_size : (i + 1) * batch_size] = features_batch
        labels[i * batch_size : (i + 1) * batch_size] = labels_batch
        if ((i + 1) * batch_size) >= sample_count:
            # Note that since generators yield data indefinitely in a loop,
            # we must `break` after every image has been seen once.
            break
    return features, labels

train_features, train_labels = extract_features(str(sample_dir / "train"), 2000)
validation_features, validation_labels = extract_features(str(sample_dir / "validation"), 1000)
test_features, test_labels = extract_features(str(sample_dir / "test"), 1000)
# Out:
# Found 2000 images belonging to 2 classes.
# Found 1000 images belonging to 2 classes.
# Found 1000 images belonging to 2 classes.
# CPU times: user 30.8 s, sys: 6.99 s, total: 37.8 s
# Wall time: 36.9 s

# %%
# %%time
train_features = np.reshape(train_features, (2000, 4 * 4 * 512))
validation_features = np.reshape(validation_features, (1000, 4 * 4 * 512))
test_features = np.reshape(test_features, (1000, 4 * 4 * 512))
# Out:
# CPU times: user 0 ns, sys: 0 ns, total: 0 ns
# Wall time: 30.5 µs

# %% [markdown]
# ## Create new dense classifier

# %%
from keras import models
from keras import layers
from keras import optimizers

model = models.Sequential()
model.add(layers.Dense(256, activation='relu', input_dim=4 * 4 * 512))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(1, activation='sigmoid'))

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 256)               2097408
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 257
# =================================================================
# Total params: 2,097,665
# Trainable params: 2,097,665
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer=optimizers.RMSprop(lr=2e-5),
              loss='binary_crossentropy',
              metrics=['acc'])

# %% [markdown]
# ## Fit model

# %%
# %%time
history = model.fit(train_features, train_labels,
                    epochs=30,
                    batch_size=20,
                    validation_data=(validation_features, validation_labels))
# Out:
# Train on 2000 samples, validate on 1000 samples
# Epoch 1/30
# 2000/2000 [==============================] - 1s 609us/step - loss: 0.5617 - acc: 0.7035 - val_loss: 0.4337 - val_acc: 0.8290
# Epoch 2/30
# 2000/2000 [==============================] - 1s 366us/step - loss: 0.4256 - acc: 0.8145 - val_loss: 0.3559 - val_acc: 0.8650
# Epoch 3/30
# 2000/2000 [==============================] - 1s 391us/step - loss: 0.3627 - acc: 0.8355 - val_loss: 0.3198 - val_acc: 0.8730
# Epoch 4/30
# 2000/2000 [==============================] - 1s 399us/step - loss: 0.3092 - acc: 0.8755 - val_loss: 0.2975 - val_acc: 0.8850
# Epoch 5/30
# 2000/2000 [==============================] - 1s 396us/step - loss: 0.2867 - acc: 0.8810 - val_loss: 0.2903 - val_acc: 0.8800
# Epoch 6/30
# 2000/2000 [==============================] - 1s 405us/step - loss: 0.2721 - acc: 0.8920 - val_loss: 0.2777 - val_acc: 0.8810
# Epoch 7/30
# 2000/2000 [==============================] - 1s 400us/step - loss: 0.2506 - acc: 0.9055 - val_loss: 0.2740 - val_acc: 0.8810
# Epoch 8/30
# 2000/2000 [==============================] - 1s 406us/step - loss: 0.2300 - acc: 0.9125 - val_loss: 0.2583 - val_acc: 0.8920
# Epoch 9/30
# 2000/2000 [==============================] - 1s 396us/step - loss: 0.2192 - acc: 0.9140 - val_loss: 0.2531 - val_acc: 0.8940
# Epoch 10/30
# 2000/2000 [==============================] - 1s 396us/step - loss: 0.2016 - acc: 0.9260 - val_loss: 0.2518 - val_acc: 0.8910
# Epoch 11/30
# 2000/2000 [==============================] - 1s 397us/step - loss: 0.1990 - acc: 0.9285 - val_loss: 0.2468 - val_acc: 0.8970
# Epoch 12/30
# 2000/2000 [==============================] - 1s 405us/step - loss: 0.1849 - acc: 0.9410 - val_loss: 0.2499 - val_acc: 0.8940
# Epoch 13/30
# 2000/2000 [==============================] - 1s 393us/step - loss: 0.1762 - acc: 0.9345 - val_loss: 0.2443 - val_acc: 0.8960
# Epoch 14/30
# 2000/2000 [==============================] - 1s 398us/step - loss: 0.1705 - acc: 0.9405 - val_loss: 0.2487 - val_acc: 0.8960
# Epoch 15/30
# 2000/2000 [==============================] - 1s 399us/step - loss: 0.1599 - acc: 0.9455 - val_loss: 0.2433 - val_acc: 0.8980
# Epoch 16/30
# 2000/2000 [==============================] - 1s 400us/step - loss: 0.1595 - acc: 0.9405 - val_loss: 0.2471 - val_acc: 0.8990
# Epoch 17/30
# 2000/2000 [==============================] - 1s 397us/step - loss: 0.1500 - acc: 0.9435 - val_loss: 0.2436 - val_acc: 0.9010
# Epoch 18/30
# 2000/2000 [==============================] - 1s 401us/step - loss: 0.1484 - acc: 0.9500 - val_loss: 0.2407 - val_acc: 0.9020
# Epoch 19/30
# 2000/2000 [==============================] - 1s 399us/step - loss: 0.1416 - acc: 0.9515 - val_loss: 0.2380 - val_acc: 0.9000
# Epoch 20/30
# 2000/2000 [==============================] - 1s 398us/step - loss: 0.1354 - acc: 0.9515 - val_loss: 0.2462 - val_acc: 0.9010
# Epoch 21/30
# 2000/2000 [==============================] - 1s 406us/step - loss: 0.1267 - acc: 0.9580 - val_loss: 0.2570 - val_acc: 0.8920
# Epoch 22/30
# 2000/2000 [==============================] - 1s 397us/step - loss: 0.1252 - acc: 0.9575 - val_loss: 0.2391 - val_acc: 0.8990
# Epoch 23/30
# 2000/2000 [==============================] - 1s 399us/step - loss: 0.1179 - acc: 0.9600 - val_loss: 0.2577 - val_acc: 0.8980
# Epoch 24/30
# 2000/2000 [==============================] - 1s 395us/step - loss: 0.1140 - acc: 0.9630 - val_loss: 0.2471 - val_acc: 0.9040
# Epoch 25/30
# 2000/2000 [==============================] - 1s 396us/step - loss: 0.1092 - acc: 0.9625 - val_loss: 0.2381 - val_acc: 0.9010
# Epoch 26/30
# 2000/2000 [==============================] - 1s 399us/step - loss: 0.1047 - acc: 0.9645 - val_loss: 0.2540 - val_acc: 0.8960
# Epoch 27/30
# 2000/2000 [==============================] - 1s 399us/step - loss: 0.0981 - acc: 0.9700 - val_loss: 0.2423 - val_acc: 0.9040
# Epoch 28/30
# 2000/2000 [==============================] - 1s 398us/step - loss: 0.1015 - acc: 0.9680 - val_loss: 0.2451 - val_acc: 0.9050
# Epoch 29/30
# 2000/2000 [==============================] - 1s 397us/step - loss: 0.0925 - acc: 0.9705 - val_loss: 0.2536 - val_acc: 0.9030
# Epoch 30/30
# 2000/2000 [==============================] - 1s 400us/step - loss: 0.0925 - acc: 0.9730 - val_loss: 0.2457 - val_acc: 0.9030
# CPU times: user 27.5 s, sys: 3.66 s, total: 31.1 s
# Wall time: 24.7 s

# %%
import json

models_dir = data_root / "models" 
models_dir.mkdir(exist_ok=True)
model.save(str(models_dir / "cats_and_dogs_feature_extraction.h5"))

history_path = models_dir / "cats_and_dogs_feature_extraction_history.json"
with open(str(history_path), "w") as f:
    json.dump(history.history, f)

# %%
history = json.load(open(str(history_path)))

# %% [markdown]
# ## Plot training vs test accuracy

# %%
import matplotlib.pyplot as plt

acc = history['acc']
val_acc = history['val_acc']
loss = history['loss']
val_loss = history['val_loss']

epochs = range(len(acc))

plt.figure(figsize=(15, 20))

plt.subplot(211)

plt.plot(epochs, acc, 'bo', label='Training acc')
plt.plot(epochs, val_acc, 'b', label='Validation acc')
plt.title('Training and validation accuracy')
plt.legend()

plt.subplot(212)

plt.plot(epochs, loss, 'bo', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.legend()

plt.show()
